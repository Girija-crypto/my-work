# %% [markdown]
# # importing library and file

# %%
import pandas as pd                #importing libraries which needs to data cleaning, manipulation and visualization
import numpy as np
import matplotlib.pyplot as plt
df = pd.read_csv("C:/Users/ELCOT/Downloads/Titanic.csv")    #import csv file for data using this function

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %% [markdown]
# # shape and size

# %%
df.shape       #checking the no of rows and columns
# Out:
# (418, 12)

# %%
df.size      #over all size  row*column
# Out:
# 5016

# %% [markdown]
# # describe and info

# %%
df.describe()               #it shows the descriptive statistics about the continuous column
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   418.000000  418.000000  418.000000  332.000000  418.000000
# mean   1100.500000    0.363636    2.265550   30.272590    0.447368
# std     120.810458    0.481622    0.841838   14.181209    0.896760
# min     892.000000    0.000000    1.000000    0.170000    0.000000
# 25%     996.250000    0.000000    1.000000   21.000000    0.000000
# 50%    1100.500000    0.000000    3.000000   27.000000    0.000000
# 75%    1204.750000    1.000000    3.000000   39.000000    1.000000
# max    1309.000000    1.000000    3.000000   76.000000    8.000000
#
#             Parch        Fare
# count  418.000000  417.000000
# mean     0.392344   35.627188
# std      0.981429   55.907576
# min      0.000000    0.000000
# 25%      0.000000    7.895800
# 50%      0.000000   14.454200
# 75%      0.000000   31.500000
# max      9.000000  512.329200

# %%
df.info()         #shows over all information about dataset and column types
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Survived     418 non-null    int64
#  2   Pclass       418 non-null    int64
#  3   Name         418 non-null    object
#  4   Sex          418 non-null    object
#  5   Age          332 non-null    float64
#  6   SibSp        418 non-null    int64
#  7   Parch        418 non-null    int64
#  8   Ticket       418 non-null    object
#  9   Fare         417 non-null    float64
#  10  Cabin        91 non-null     object
#  11  Embarked     418 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 39.3+ KB

# %% [markdown]
# # column names of dataset

# %%
df.columns     #diaplay all the column names
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %% [markdown]
# # indexing

# %%
df[1:4]      #retrieving values using indexing
# Out:
#    PassengerId  Survived  Pclass                              Name     Sex  \
# 1          893         1       3  Wilkes, Mrs. James (Ellen Needs)  female
# 2          894         0       2         Myles, Mr. Thomas Francis    male
# 3          895         0       3                  Wirz, Mr. Albert    male
#
#     Age  SibSp  Parch  Ticket    Fare Cabin Embarked
# 1  47.0      1      0  363272  7.0000   NaN        S
# 2  62.0      0      0  240276  9.6875   NaN        Q
# 3  27.0      0      0  315154  8.6625   NaN        S

# %%
df[1:200:3].head()
# Out:
#     PassengerId  Survived  Pclass  \
# 1           893         1       3
# 4           896         1       3
# 7           899         0       2
# 10          902         0       3
# 13          905         0       2
#
#                                             Name     Sex   Age  SibSp  Parch  \
# 1               Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 4   Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# 7                   Caldwell, Mr. Albert Francis    male  26.0      1      1
# 10                              Ilieff, Mr. Ylio    male   NaN      0      0
# 13                          Howard, Mr. Benjamin    male  63.0      1      0
#
#      Ticket     Fare Cabin Embarked
# 1    363272   7.0000   NaN        S
# 4   3101298  12.2875   NaN        S
# 7    248738  29.0000   NaN        S
# 10   349220   7.8958   NaN        S
# 13    24065  26.0000   NaN        S

# %%
df[415:]
# Out:
#      PassengerId  Survived  Pclass                          Name   Sex   Age  \
# 415         1307         0       3  Saether, Mr. Simon Sivertsen  male  38.5
# 416         1308         0       3           Ware, Mr. Frederick  male   NaN
# 417         1309         0       3      Peter, Master. Michael J  male   NaN
#
#      SibSp  Parch              Ticket     Fare Cabin Embarked
# 415      0      0  SOTON/O.Q. 3101262   7.2500   NaN        S
# 416      0      0              359309   8.0500   NaN        S
# 417      1      1                2668  22.3583   NaN        C

# %%
df[:7]
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
# 5          897         0       3
# 6          898         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# 5                    Svensson, Mr. Johan Cervin    male  14.0      0      0
# 6                          Connolly, Miss. Kate  female  30.0      0      0
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# ...

# %% [markdown]
# # head and tail

# %%
df.head()      # defaultly it shows first five rows of a dataset
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
df.head(3)
# Out:
#    PassengerId  Survived  Pclass                              Name     Sex  \
# 0          892         0       3                  Kelly, Mr. James    male
# 1          893         1       3  Wilkes, Mrs. James (Ellen Needs)  female
# 2          894         0       2         Myles, Mr. Thomas Francis    male
#
#     Age  SibSp  Parch  Ticket    Fare Cabin Embarked
# 0  34.5      0      0  330911  7.8292   NaN        Q
# 1  47.0      1      0  363272  7.0000   NaN        S
# 2  62.0      0      0  240276  9.6875   NaN        Q

# %%
df.tail()     #it shows last five rows
# Out:
#      PassengerId  Survived  Pclass                          Name     Sex  \
# 413         1305         0       3            Spector, Mr. Woolf    male
# 414         1306         1       1  Oliva y Ocana, Dona. Fermina  female
# 415         1307         0       3  Saether, Mr. Simon Sivertsen    male
# 416         1308         0       3           Ware, Mr. Frederick    male
# 417         1309         0       3      Peter, Master. Michael J    male
#
#       Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# 413   NaN      0      0           A.5. 3236    8.0500   NaN        S
# 414  39.0      0      0            PC 17758  108.9000  C105        C
# 415  38.5      0      0  SOTON/O.Q. 3101262    7.2500   NaN        S
# 416   NaN      0      0              359309    8.0500   NaN        S
# 417   NaN      1      1                2668   22.3583   NaN        C

# %%
df.tail(4)
# Out:
#      PassengerId  Survived  Pclass                          Name     Sex  \
# 414         1306         1       1  Oliva y Ocana, Dona. Fermina  female
# 415         1307         0       3  Saether, Mr. Simon Sivertsen    male
# 416         1308         0       3           Ware, Mr. Frederick    male
# 417         1309         0       3      Peter, Master. Michael J    male
#
#       Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# 414  39.0      0      0            PC 17758  108.9000  C105        C
# 415  38.5      0      0  SOTON/O.Q. 3101262    7.2500   NaN        S
# 416   NaN      0      0              359309    8.0500   NaN        S
# 417   NaN      1      1                2668   22.3583   NaN        C

# %% [markdown]
# # mean, median and mode

# %%
df.Fare.mean()     #mean value of a particular column
# Out:
# 35.6271884892086

# %%
df.Age.median()     #median of specific column
# Out:
# 27.0

# %%
df.Sex.mode()      #checking mode for categorical column
# Out:
# 0    male
# Name: Sex, dtype: object

# %% [markdown]
# # value counts and unique value

# %%
df.SibSp.value_counts()     #how many times different values occurs
# Out:
# 0    283
# 1    110
# 2     14
# 3      4
# 4      4
# 8      2
# 5      1
# Name: SibSp, dtype: int64

# %%
df.SibSp.nunique()     #how many different values are exist in a specific col
# Out:
# 7

# %% [markdown]
# # variance, maximum and minimum value

# %%
df.Fare.var()     #finding variance for one column
# Out:
# 3125.6570743195775

# %%
df.max()    #this method used to find out maximum value
# Out:
# C:\Users\ELCOT\AppData\Local\Temp\ipykernel_11424\3936002508.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.max()    #this method used to find out maximum value
# PassengerId                                 1309
# Survived                                       1
# Pclass                                         3
# Name           van Billiard, Master. Walter John
# Sex                                         male
# Age                                         76.0
# SibSp                                          8
# Parch                                          9
# Ticket                               W.E.P. 5734
# Fare                                    512.3292
# Embarked                                       S
# dtype: object

# %%
df.Fare.max()    #maximum value of specific column
# Out:
# 512.3292

# %%
df.Fare.min()    #min value of specific column
# Out:
# 0.0

# %%
df.var()  #variance for whole dataset in columnwise
# Out:
# C:\Users\ELCOT\AppData\Local\Temp\ipykernel_11424\3505674069.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.var()  #variance for whole dataset in columnwise
# PassengerId    14595.166667
# Survived           0.231960
# Pclass             0.708690
# Age              201.106695
# SibSp              0.804178
# Parch              0.963203
# Fare            3125.657074
# dtype: float64

# %%
df.Age.var()     #variance of a specific column
# Out:
# 201.10669538455937

# %% [markdown]
# # extracting by colulmn name

# %%
df["Name"]      #extracting one column
# Out:
# 0                                  Kelly, Mr. James
# 1                  Wilkes, Mrs. James (Ellen Needs)
# 2                         Myles, Mr. Thomas Francis
# 3                                  Wirz, Mr. Albert
# 4      Hirvonen, Mrs. Alexander (Helga E Lindqvist)
#                            ...
# 413                              Spector, Mr. Woolf
# 414                    Oliva y Ocana, Dona. Fermina
# 415                    Saether, Mr. Simon Sivertsen
# 416                             Ware, Mr. Frederick
# 417                        Peter, Master. Michael J
# Name: Name, Length: 418, dtype: object

# %% [markdown]
# # giving condition

# %%
df[df.Sex == "female"]     #giving condition what data I want
# Out:
#      PassengerId  Survived  Pclass  \
# 1            893         1       3
# 4            896         1       3
# 6            898         1       3
# 8            900         1       3
# 12           904         1       1
# ..           ...       ...     ...
# 409         1301         1       3
# 410         1302         1       3
# 411         1303         1       1
# 412         1304         1       3
# 414         1306         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 1                   Wilkes, Mrs. James (Ellen Needs)  female  47.0      1
# 4       Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1
# 6                               Connolly, Miss. Kate  female  30.0      0
# 8          Abrahim, Mrs. Joseph (Sophie Halaut Easu)  female  18.0      0
# 12     Snyder, Mrs. John Pillsbury (Nelle Stevenson)  female  23.0      1
# ..                                               ...     ...   ...    ...
# ...

# %%
df[(df.Sex == "male") & (df.Pclass == 3)]    #more than one condition
# Out:
#      PassengerId  Survived  Pclass                          Name   Sex   Age  \
# 0            892         0       3              Kelly, Mr. James  male  34.5
# 3            895         0       3              Wirz, Mr. Albert  male  27.0
# 5            897         0       3    Svensson, Mr. Johan Cervin  male  14.0
# 9            901         0       3       Davies, Mr. John Samuel  male  21.0
# 10           902         0       3              Ilieff, Mr. Ylio  male   NaN
# ..           ...       ...     ...                           ...   ...   ...
# 399         1291         0       3      Conlon, Mr. Thomas Henry  male  31.0
# 413         1305         0       3            Spector, Mr. Woolf  male   NaN
# 415         1307         0       3  Saether, Mr. Simon Sivertsen  male  38.5
# 416         1308         0       3           Ware, Mr. Frederick  male   NaN
# 417         1309         0       3      Peter, Master. Michael J  male   NaN
#
# ...

# %%
df[(df.Survived == 1) & (df.Parch == 0) & (df.Embarked == "Q")]
# Out:
#      PassengerId  Survived  Pclass  \
# 6            898         1       3
# 63           955         1       3
# 66           958         1       3
# 70           962         1       3
# 79           971         1       3
# 86           978         1       3
# 88           980         1       3
# 111         1003         1       3
# 113         1005         1       3
# 127         1019         1       3
# 160         1052         1       3
# 200         1092         1       3
# 206         1098         1       3
# 216         1108         1       3
# 227         1119         1       3
# 273         1165         1       3
# 282         1174         1       3
# 291         1183         1       3
# 304         1196         1       3
# 313         1205         1       3
# 315         1207         1       3
# 408         1300         1       3
# 410         1302         1       3
# 411         1303         1       1
#
# ...

# %% [markdown]
# # loc and iloc function

# %%
df.loc[4:8]      #loc is used for accessing multiple rows and columns
# Out:
#    PassengerId  Survived  Pclass  \
# 4          896         1       3
# 5          897         0       3
# 6          898         1       3
# 7          899         0       2
# 8          900         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# 5                    Svensson, Mr. Johan Cervin    male  14.0      0      0
# 6                          Connolly, Miss. Kate  female  30.0      0      0
# 7                  Caldwell, Mr. Albert Francis    male  26.0      1      1
# 8     Abrahim, Mrs. Joseph (Sophie Halaut Easu)  female  18.0      0      0
#
#     Ticket     Fare Cabin Embarked
# 4  3101298  12.2875   NaN        S
# 5     7538   9.2250   NaN        S
# 6   330972   7.6292   NaN        Q
# 7   248738  29.0000   NaN        S
# 8     2657   7.2292   NaN        C

# %%
df.loc[[3,4,6,7], "Name"]
# Out:
# 3                                Wirz, Mr. Albert
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# 6                            Connolly, Miss. Kate
# 7                    Caldwell, Mr. Albert Francis
# Name: Name, dtype: object

# %%
df.loc[3:8, ["Name", "Sex","Age"]]
# Out:
#                                            Name     Sex   Age
# 3                              Wirz, Mr. Albert    male  27.0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0
# 5                    Svensson, Mr. Johan Cervin    male  14.0
# 6                          Connolly, Miss. Kate  female  30.0
# 7                  Caldwell, Mr. Albert Francis    male  26.0
# 8     Abrahim, Mrs. Joseph (Sophie Halaut Easu)  female  18.0

# %%
df.iloc[2:7,3:5]   #iloc is used for integer based accessing
# Out:
#                                            Name     Sex
# 2                     Myles, Mr. Thomas Francis    male
# 3                              Wirz, Mr. Albert    male
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
# 5                    Svensson, Mr. Johan Cervin    male
# 6                          Connolly, Miss. Kate  female

# %%
df.iloc[:,2:6]
# Out:
#      PassengerClass                                          Name     Sex  \
# 0                 3                              Kelly, Mr. James    male
# 1                 3              Wilkes, Mrs. James (Ellen Needs)  female
# 2                 2                     Myles, Mr. Thomas Francis    male
# 3                 3                              Wirz, Mr. Albert    male
# 4                 3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
# ..              ...                                           ...     ...
# 413               3                            Spector, Mr. Woolf    male
# 414               1                  Oliva y Ocana, Dona. Fermina  female
# 415               3                  Saether, Mr. Simon Sivertsen    male
# 416               3                           Ware, Mr. Frederick    male
# 417               3                      Peter, Master. Michael J    male
#
#       Age
# 0    34.5
# 1    47.0
# 2    62.0
# 3    27.0
# 4    22.0
# ...

# %% [markdown]
# # groupby function

# %%
df.groupby("Fare").PassengerId.sum()   #used to group more than one column
# Out:
# Fare
# 0.0000      2422
# 3.1708       913
# 6.4375      2033
# 6.4958      1124
# 6.9500      1183
#             ...
# 227.5250    1094
# 247.5208    1076
# 262.3750    5124
# 263.0000    1906
# 512.3292    1235
# Name: PassengerId, Length: 169, dtype: int64

# %%
df.groupby("Age").Ticket.min()
# Out:
# Age
# 0.17              C.A. 2315
# 0.33                 347080
# 0.75     SOTON/O.Q. 3101315
# 0.83                 392091
# 0.92             C.A. 34651
#                 ...
# 62.00                240276
# 63.00                 24065
# 64.00                110813
# 67.00              PC 17483
# 76.00                 19877
# Name: Ticket, Length: 79, dtype: object

# %%
df.groupby(["Pclass","Age"]).sum()
# Out:
#              PassengerId  Survived  SibSp  Parch      Fare
# Pclass Age
# 1      6.0          1088         0      0      2  134.5000
#        13.0          956         0      2      2  262.3750
#        17.0         1295         0      0      0   47.1000
#        18.0         2361         2      2      0  113.1000
#        21.0         2038         1      0      1   87.9292
# ...                  ...       ...    ...    ...       ...
# 3      43.0         1026         0      0      0    7.8958
#        45.0         2112         2      1      0   21.3333
#        47.0          893         1      1      0    7.0000
#        50.0          917         0      1      0   14.5000
#        60.5         1044         0      0      0    0.0000
#
# [141 rows x 5 columns]

# %% [markdown]
# # sorting values

# %%
df.sort_values(by="Name")   #it is used to sorting the values by ascending order
# Out:
#      PassengerId  Survived  PassengerClass  \
# 392         1284         0               3
# 345         1237         1               3
# 57           949         0               3
# 251         1143         0               3
# 8            900         1               3
# ..           ...       ...             ...
# 336         1228         0               2
# 260         1152         0               3
# 15           907         1               2
# 344         1236         0               3
# 192         1084         0               3
#
#                                               Name     Sex   Age  SibSp  \
# 392                  Abbott, Master. Eugene Joseph    male  13.0      0
# 345                    Abelseth, Miss. Karen Marie  female  16.0      0
# 57                   Abelseth, Mr. Olaus Jorgensen    male  25.0      0
# 251       Abrahamsson, Mr. Abraham August Johannes    male  20.0      0
# 8        Abrahim, Mrs. Joseph (Sophie Halaut Easu)  female  18.0      0
# ...

# %% [markdown]
# # dropping and renaming column

# %%
df.drop(columns = ["Parch", "SibSp"])    #dropping column using column name
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  \
# 0                                Kelly, Mr. James    male  34.5
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0
# 2                       Myles, Mr. Thomas Francis    male  62.0
# 3                                Wirz, Mr. Albert    male  27.0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0
# ..                                            ...     ...   ...
# 413                            Spector, Mr. Woolf    male   NaN
# ...

# %%
df.drop(columns = ["Parch", "SibSp"], inplace = True)   #giving inplace = true to make a change in original data

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  \
# 0                                Kelly, Mr. James    male  34.5
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0
# 2                       Myles, Mr. Thomas Francis    male  62.0
# 3                                Wirz, Mr. Albert    male  27.0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0
# ..                                            ...     ...   ...
# 413                            Spector, Mr. Woolf    male   NaN
# ...

# %%
df.rename(columns={"Pclass":"PassengerClass"}, inplace=True)  #this function is used to rename the column names
df.head()
# Out:
#    PassengerId  Survived  PassengerClass  \
# 0          892         0               3
# 1          893         1               3
# 2          894         0               2
# 3          895         0               3
# 4          896         1               3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %% [markdown]
# # checking null values

# %%
df.isna().any()   #checking whether null values are exist or not
# Out:
# PassengerId    False
# Survived       False
# Pclass         False
# Name           False
# Sex            False
# Age             True
# Ticket         False
# Fare            True
# Cabin           True
# Embarked       False
# dtype: bool

# %%
df.isna().sum()   #checking total no of null values for each column
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
df.columns[df.isna().any()].tolist()   #listing the columns which have null values
# Out:
# ['Age', 'Fare', 'Cabin']

# %% [markdown]
# # dropna( )

# %%
df.dropna()   #defaultly this function remove the rows which have null values
# Out:
#      PassengerId  Survived  PassengerClass  \
# 12           904         1               1
# 14           906         1               1
# 24           916         1               1
# 26           918         1               1
# 28           920         0               1
# ..           ...       ...             ...
# 404         1296         0               1
# 405         1297         0               2
# 407         1299         0               1
# 411         1303         1               1
# 414         1306         1               1
#
#                                                   Name     Sex   Age  SibSp  \
# 12       Snyder, Mrs. John Pillsbury (Nelle Stevenson)  female  23.0      1
# 14   Chaffee, Mrs. Herbert Fuller (Carrie Constance...  female  47.0      1
# 24     Ryerson, Mrs. Arthur Larned (Emily Maria Borie)  female  48.0      1
# 26                        Ostby, Miss. Helene Ragnhild  female  22.0      0
# ...

# %%
df.dropna(axis=1)      #(axis=1) is for removing the column of null values
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex              Ticket  \
# 0                                Kelly, Mr. James    male              330911
# 1                Wilkes, Mrs. James (Ellen Needs)  female              363272
# 2                       Myles, Mr. Thomas Francis    male              240276
# 3                                Wirz, Mr. Albert    male              315154
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female             3101298
# ...

# %% [markdown]
# # fillna( ) function

# %%
df.fillna("Yes")    #this is used to filling the null values, we can give what to fill inside the paranthesis
# Out:
#      PassengerId  Survived  PassengerClass  \
# 0            892         0               3
# 1            893         1               3
# 2            894         0               2
# 3            895         0               3
# 4            896         1               3
# ..           ...       ...             ...
# 413         1305         0               3
# 414         1306         1               1
# 415         1307         0               3
# 416         1308         0               3
# 417         1309         0               3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# ...

# %% [markdown]
# # Checking data type of columns

# %%
df["Age"].dtype    #checking data type for particular column
# Out:
# dtype('float64')

# %%
df["Fare"].dtype
# Out:
# dtype('float64')

# %%
df["Cabin"].dtype
# Out:
# dtype('O')

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age        Fare
# count   418.000000  418.000000  418.000000  332.000000  417.000000
# mean   1100.500000    0.363636    2.265550   30.272590   35.627188
# std     120.810458    0.481622    0.841838   14.181209   55.907576
# min     892.000000    0.000000    1.000000    0.170000    0.000000
# 25%     996.250000    0.000000    1.000000   21.000000    7.895800
# 50%    1100.500000    0.000000    3.000000   27.000000   14.454200
# 75%    1204.750000    1.000000    3.000000   39.000000   31.500000
# max    1309.000000    1.000000    3.000000   76.000000  512.329200

# %% [markdown]
# # filling null values

# %%
df["Age"] = df.Age.fillna(df.Age.mean())      #filling null values using fillna method (filling mean of the row)

# %%
df["Fare"] = df.Age.fillna(df.Age.median())     #filling median because it has outlayers

# %%
df.Cabin.mode()
# Out:
# 0    B57 B59 B63 B66
# Name: Cabin, dtype: object

# %%
df["Cabin"] = df.Cabin.fillna(df.Cabin.mode()[0])      #filling mode because it is a categorical col

# %%
df.isna().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %% [markdown]
# # plot

# %%
df.boxplot(figsize=(6,6), color="red", rot=60)    #boxplot is used for chekcing outlayers
plt.show()

# %%
df.boxplot(figsize=(6,6), color="red", rot=90, grid = False)   #viewing without grid
# Out:
# <AxesSubplot:>

# %%
df.plot()
plt.show()

# %%
df.Fare.plot(kind="box")
# Out:
# <AxesSubplot:>

# %%
df.plot(kind = "scatter", x = "Fare", y = "Age", color = "green")  #scatterplot used to check two columns of continous values
# Out:
# <AxesSubplot:xlabel='Fare', ylabel='Age'>

# %%
df.hist("Age")
# Out:
# array([[<AxesSubplot:title={'center':'Age'}>]], dtype=object)

# %%
df["Embarked"].value_counts().plot(kind="bar")
plt.title("different Embarked")
plt.show()
